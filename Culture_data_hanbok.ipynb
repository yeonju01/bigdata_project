# %% [markdown]
# # 4대궁 및 종묘 한복착용 입장객 현황

# %% [markdown]
# ## 1. 데이터 준비

# %%
import pandas as pd
import numpy as np
df_seoulHanbok2020 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_궁능유적본부_4대궁 및 종묘 한복착용 입장객 현황_20201231.csv', encoding='cp949')
df_seoulHanbok2019 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2019년.csv', encoding='cp949')
df_seoulHanbok2018 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2018년.csv', encoding='cp949')
df_seoulHanbok2017 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2017년.csv', encoding='cp949')
df_seoulHanbok2016 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2016년.csv', encoding='cp949')
#df_seoulHanbok2015 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2015년.csv', encoding='cp949')
#df_seoulHanbok2014 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2014년.csv', encoding='cp949')
#df_seoulHanbok2013 = pd.read_csv('/Users/yeonju1/Documents/bigData/src/07_Python/Project1/data/한복/문화재청_4대궁및종묘 한복착용 입장객현황_2013년.csv', encoding='cp949')

df_seoulHanbok2020.count(), df_seoulHanbok2016.count()
# Out:
# (2020년            12
#  경복궁(주·야간 착용자)    12
#  창덕궁(주·야간 착용자)    12
#  덕수궁(주·야간 착용자)    12
#  창경궁(주·야간 착용자)    12
#  종묘(주간 착용자)       12
#  dtype: int64,
#  2016년            12
#  경복궁(주·야간 착용자)    12
#  창덕궁(주·야간 착용자)    12
#  덕수궁(주·야간 착용자)    12
#  창경궁(주·야간 착용자)    12
#  종묘(주간 착용자)       12
#  dtype: int64)

# %%
df_seoulHanbok2016.columns
# Out:
# Index(['2016년', '경복궁(주·야간 착용자)', '창덕궁(주·야간 착용자)', '덕수궁(주·야간 착용자)',
#        '창경궁(주·야간 착용자)', '종묘(주간 착용자)'],
#       dtype='object')

# %%
df_seoulHanbok2020 = pd.melt(df_seoulHanbok2020, 
                             id_vars=['경복궁(주·야간 착용자)','창덕궁(주·야간 착용자)',
                                     '덕수궁(주·야간 착용자)','창경궁(주·야간 착용자)',
                                     '종묘(주간 착용자)'], value_vars='2020년')
df_seoulHanbok2019 = pd.melt(df_seoulHanbok2019, 
                             id_vars=['경복궁(주·야간 착용자)','창덕궁(주·야간 착용자)',
                                     '덕수궁(주·야간 착용자)','창경궁(주·야간 착용자)',
                                     '종묘(주간 착용자)'], value_vars='2019년')
df_seoulHanbok2018 = pd.melt(df_seoulHanbok2018, 
                             id_vars=['경복궁(주·야간 착용자)','창덕궁(주·야간 착용자)',
                                     '덕수궁(주·야간 착용자)','창경궁(주·야간 착용자)',
                                     '종묘(주간 착용자)'], value_vars='2018년')
df_seoulHanbok2017 = pd.melt(df_seoulHanbok2017, 
                             id_vars=['경복궁(주·야간 착용자)','창덕궁(주·야간 착용자)',
                                     '덕수궁(주·야간 착용자)','창경궁(주·야간 착용자)',
                                     '종묘(주간 착용자)'], value_vars='2017년')
df_seoulHanbok2016 = pd.melt(df_seoulHanbok2016, 
                             id_vars=['경복궁(주·야간 착용자)','창덕궁(주·야간 착용자)',
                                     '덕수궁(주·야간 착용자)','창경궁(주·야간 착용자)',
                                     '종묘(주간 착용자)'], value_vars='2016년')
# df_seoulHanbok2015 = pd.melt(df_seoulHanbok2015, 
#                              id_vars=['경복궁(주간 착용자)','창덕궁(주간 착용자)',
#                                      '덕수궁(주간 착용자)','창경궁(주간 착용자)',
#                                      '종묘(주간 착용자)'], value_vars='2015년')
# df_seoulHanbok2014 = pd.melt(df_seoulHanbok2014, 
#                              id_vars=['경복궁(주간 착용자)','창덕궁(주간 착용자)',
#                                      '덕수궁(주간 착용자)','창경궁(주간 착용자)',
#                                      '종묘(주간 착용자)'], value_vars='2014년')
# df_seoulHanbok2013 = pd.melt(df_seoulHanbok2013, 
#                              id_vars=['경복궁(주간 착용자)','창덕궁(주간 착용자)',
#                                      '덕수궁(주간 착용자)','창경궁(주간 착용자)',
#                                      '종묘(주간 착용자)'], value_vars='2013년')

# %%
df_seoulHanbok = pd.concat([df_seoulHanbok2020, df_seoulHanbok2019, df_seoulHanbok2018,
                           df_seoulHanbok2017, df_seoulHanbok2016], axis=0)
df_seoulHanbok.dropna(inplace=True)
df_seoulHanbok.rename(columns={'variable':'연도','value':'월'}, inplace=True)
df_seoulHanbok.head(6)
# Out:
#   경복궁(주·야간 착용자) 창덕궁(주·야간 착용자) 덕수궁(주·야간 착용자) 창경궁(주·야간 착용자)  종묘(주간 착용자)     연도  \
# 0        63,939         6,797         206.0           921        12.0  2020년
# 1        27,365         3,010         209.0           483        13.0  2020년
# 2         2,282           927          38.0           225         0.0  2020년
# 3         3,533           976          50.0           395        13.0  2020년
# 4         4,397         1,133          81.0           414         9.0  2020년
# 5             0             0           0.0             0         0.0  2020년
#
#     월
# 0  1월
# 1  2월
# 2  3월
# 3  4월
# 4  5월
# 5  6월

# %% [markdown]
# ## 2. 데이터정제

# %%
df_seoulHanbok.groupby(['연도']).count().T
# Out:
# 연도             2016년  2017년  2018년  2019년  2020년
# 경복궁(주·야간 착용자)     12     12     12     12     12
# 창덕궁(주·야간 착용자)     12     12     12     12     12
# 덕수궁(주·야간 착용자)     12     12     12     12     12
# 창경궁(주·야간 착용자)     12     12     12     12     12
# 종묘(주간 착용자)        12     12     12     12     12
# 월                 12     12     12     12     12

# %%
df_seoulHanbok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   경복궁(주·야간 착용자)  60 non-null     object
#  1   창덕궁(주·야간 착용자)  60 non-null     object
#  2   덕수궁(주·야간 착용자)  60 non-null     object
#  3   창경궁(주·야간 착용자)  60 non-null     object
#  4   종묘(주간 착용자)     60 non-null     float64
#  5   연도             60 non-null     object
#  6   월              60 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 3.8+ KB

# %%
# df_seoulHanbok.iloc[:,:4]
df_seoulHanbok.iloc[:,0] = df_seoulHanbok.iloc[:,0].str.replace(',', '').astype('int64')
df_seoulHanbok.iloc[:,1] = df_seoulHanbok.iloc[:,1].str.replace(',', '').astype('int64', errors='ignore')
#df_seoulHanbok.iloc[:,2] = df_seoulHanbok.iloc[:,2].str.replace('.0', '').astype('int64', errors='ignore')
df_seoulHanbok['덕수궁(주·야간 착용자)'] = pd.to_numeric(df_seoulHanbok['덕수궁(주·야간 착용자)'], errors='coerce')
df_seoulHanbok.iloc[:,3] = df_seoulHanbok.iloc[:,3].str.replace(',', '').astype('int64', errors='ignore')
df_seoulHanbok.head(6)
# Out:
#    경복궁(주·야간 착용자)  창덕궁(주·야간 착용자)  덕수궁(주·야간 착용자)  창경궁(주·야간 착용자)  종묘(주간 착용자)  \
# 0          63939           6797          206.0            921        12.0
# 1          27365           3010          209.0            483        13.0
# 2           2282            927           38.0            225         0.0
# 3           3533            976           50.0            395        13.0
# 4           4397           1133           81.0            414         9.0
# 5              0              0            0.0              0         0.0
#
#       연도   월
# 0  2020년  1월
# 1  2020년  2월
# 2  2020년  3월
# 3  2020년  4월
# 4  2020년  5월
# 5  2020년  6월

# %%
df_seoulHanbok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   경복궁(주·야간 착용자)  60 non-null     int64
#  1   창덕궁(주·야간 착용자)  60 non-null     int64
#  2   덕수궁(주·야간 착용자)  56 non-null     float64
#  3   창경궁(주·야간 착용자)  60 non-null     int64
#  4   종묘(주간 착용자)     60 non-null     float64
#  5   연도             60 non-null     object
#  6   월              60 non-null     object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 3.8+ KB

# %%
df_seoulHanbok.groupby(['연도']).count().T
# Out:
# 연도             2016년  2017년  2018년  2019년  2020년
# 경복궁(주·야간 착용자)     12     12     12     12     12
# 창덕궁(주·야간 착용자)     12     12     12     12     12
# 덕수궁(주·야간 착용자)     10     11     11     12     12
# 창경궁(주·야간 착용자)     12     12     12     12     12
# 종묘(주간 착용자)        12     12     12     12     12
# 월                 12     12     12     12     12

# %% [markdown]
# ## 3. 분석 및 시각화

# %%
# 시작전 설정
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# 한글설정
#plt.rc('font', family='Malgun Gothic')
plt.rc('font', family='AppleGothic')
plt.rc('axes', unicode_minus=False)
# 경고메세지 안보이게
import warnings
warnings.filterwarnings(action='ignore')

# %%
x = np.arange(0, 10, 0.01)
plt.plot(x, np.sin(x)) 
plt.suptitle('테스트')
# Out:
# Text(0.5, 0.98, '테스트')

# %%
df_seoulHanbok.groupby(['연도']).describe().T
# Out:
# 연도                           2016년         2017년         2018년          2019년  \
# 경복궁(주·야간 착용자) count      12.000000     12.000000     12.000000      12.000000
#               mean    24047.500000  42408.416667  57000.750000   79505.583333
#               std     29627.280238  20218.829057  22356.944657   24258.929252
#               min         0.000000  19290.000000  22772.000000   32084.000000
#               25%      4799.500000  28445.250000  36253.250000   68819.000000
#               50%     20230.000000  33643.000000  58105.000000   82468.500000
#               75%     26014.000000  53923.000000  81634.250000  100445.250000
#               max    108549.000000  88640.000000  83659.000000  109353.000000
# 창덕궁(주·야간 착용자) count      12.000000     12.000000     12.000000      12.000000
#               mean     4030.583333   7564.083333  11040.000000   13726.333333
#               std      2306.425785   3922.649602   5150.519215    8524.116625
# ...

# %%
df_seoulHanbok.groupby(['연도']).mean()
# Out:
#        경복궁(주·야간 착용자)  창덕궁(주·야간 착용자)  덕수궁(주·야간 착용자)  창경궁(주·야간 착용자)  종묘(주간 착용자)
# 연도
# 2016년   24047.500000    4030.583333     450.600000     987.000000   94.166667
# 2017년   42408.416667    7564.083333     414.000000    2054.916667   71.416667
# 2018년   57000.750000   11040.000000     328.727273    2149.250000   44.500000
# 2019년   79505.583333   13726.333333     456.083333    2166.666667   27.583333
# 2020년   10814.333333    1585.250000      80.833333     421.750000    8.166667

# %%
g = df_seoulHanbok.groupby(['연도']).mean().T
g.plot(kind='bar', rot=0, figsize=(10,8))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
g.plot(kind='box',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
t = df_seoulHanbok.groupby('연도')
t

# %%
t.plot(kind='bar', rot=0, figsize=(10,3))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
r = df_seoulHanbok.groupby('연도')['경복궁(주·야간 착용자)'].mean()
sns.barplot(data=r.to_frame(), x=r.index, y=r, color='skyblue')
# Out:
# <AxesSubplot:xlabel='연도', ylabel='경복궁(주·야간 착용자)'>

# %%
r = df_seoulHanbok.groupby('연도')['경복궁(주·야간 착용자)'].mean()
sns.lineplot(data=r.to_frame(), x=r.index, y=r, color='skyblue')
# Out:
# <AxesSubplot:xlabel='연도', ylabel='경복궁(주·야간 착용자)'>

# %%
ax = sns.boxplot(data=df_seoulHanbok.sort_values('연도'), x="연도", y="경복궁(주·야간 착용자)", color='skyblue')
#ax.set_ylim([0, 200000]) 
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(17,10))
plt.subplots_adjust(wspace=0.2) # 서브플롯 사이의 패딩 너비 조정

sns.lineplot(data=df_seoulHanbok.sort_values('연도', ascending=True), x='연도', y='경복궁(주·야간 착용자)',  ci=None, ax=axes[0,0]) #ax=axes[0]사용
sns.barplot(data=df_seoulHanbok.sort_values('연도'), x='연도', y='경복궁(주·야간 착용자)', ci=None, ax=axes[0,1])
sns.barplot(data=df_seoulHanbok, x='월', y='경복궁(주·야간 착용자)', ax=axes[1,0])
sns.lineplot(data=df_seoulHanbok.sort_values('연도'), x='월', y='경복궁(주·야간 착용자)', ci=None, ax=axes[1,1])
#plt.savefig('Culture_data_hanbok_graph01.png') # 저장
plt.show()

# %%
sns.set(style='darkgrid') # darkgrid, whitegrid, dark, white(기본값), ticks
sns.relplot(data=df_seoulHanbok.sort_values('연도'), x='월', y='경복궁(주·야간 착용자)', hue='연도',
           kind='line', # 기본값은 scatter
           col='연도', # col단위로 서브플롯 표현
           col_wrap=5) # 한 줄에 표현될 서브플롯 수

# %%
sns.relplot(data=df_seoulHanbok.sort_values('연도'), x='월', y='창덕궁(주·야간 착용자)', hue='연도',
           kind='line', # 기본값은 scatter
           col='연도', # col단위로 서브플롯 표현
           col_wrap=5) # 한 줄에 표현될 서브플롯 수

# %%
sns.relplot(data=df_seoulHanbok.sort_values('연도'), x='월', y='창경궁(주·야간 착용자)', hue='연도',
           kind='line', # 기본값은 scatter
           col='연도', # col단위로 서브플롯 표현
           col_wrap=5) # 한 줄에 표현될 서브플롯 수

# %%
sns.relplot(data=df_seoulHanbok.sort_values('연도'), x='월', y='덕수궁(주·야간 착용자)', hue='연도',
           kind='line', # 기본값은 scatter
           col='연도', # col단위로 서브플롯 표현
           col_wrap=5) # 한 줄에 표현될 서브플롯 수

# %%
g = sns.catplot(data=df_seoulHanbok, col="연도", ci=None, col_wrap=1, sharey=True, sharex=True, kind='bar')
#g.set_xticklabels(g.get_xticklabels(),rotation = 30)

locs, labels = plt.xticks()
plt.setp(labels, rotation=60)

# ax = sns.barplot(x = 'Date', y = 'Price',data = df)
# ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
#plt.figure(figsize=(20,50))
g = sns.catplot(data=df_seoulHanbok.sort_values('연도'), col="연도", ci=None, col_wrap=5, sharey=True, sharex=True, kind='bar', height=8, aspect=5/8)
g.set_xticklabels(Rotation= 45)
#plt.ylim(0,60000)

# %% [markdown]
# ## 5. 추가분석

# %%
plt.figure(figsize=(10,5))
sns.set_context('notebook') # 배율
# notebook(기본값:1배율, paper:0.8, tali:1.3, poster:1.8)
sns.lineplot(data=df_seoulHanbok, x='경복궁(주·야간 착용자)', y='창덕궁(주·야간 착용자)')
sns.scatterplot(data=df_seoulHanbok, x='경복궁(주·야간 착용자)', y='창덕궁(주·야간 착용자)')
# Out:
# <AxesSubplot:xlabel='경복궁(주·야간 착용자)', ylabel='창덕궁(주·야간 착용자)'>

# %%
fig, axes = plt.subplots(ncols=2, figsize=(15,5))
plt.subplots_adjust(wspace=0.3)
sns.scatterplot(data=df_seoulHanbok, x='경복궁(주·야간 착용자)', y='창덕궁(주·야간 착용자)', hue='연도', ax=axes[0])
sns.scatterplot(data=df_seoulHanbok, x='덕수궁(주·야간 착용자)', y='창경궁(주·야간 착용자)', hue='연도', ax=axes[1])
# Out:
# <AxesSubplot:xlabel='덕수궁(주·야간 착용자)', ylabel='창경궁(주·야간 착용자)'>

# %%
df_seoulHanbok["연도월"] = df_seoulHanbok["연도"] + df_seoulHanbok["월"]
df_seoulHanbok.head()
# Out:
#    경복궁(주·야간 착용자)  창덕궁(주·야간 착용자)  덕수궁(주·야간 착용자)  창경궁(주·야간 착용자)  종묘(주간 착용자)  \
# 0          63939           6797          206.0            921        12.0
# 1          27365           3010          209.0            483        13.0
# 2           2282            927           38.0            225         0.0
# 3           3533            976           50.0            395        13.0
# 4           4397           1133           81.0            414         9.0
#
#       연도   월      연도월
# 0  2020년  1월  2020년1월
# 1  2020년  2월  2020년2월
# 2  2020년  3월  2020년3월
# 3  2020년  4월  2020년4월
# 4  2020년  5월  2020년5월

# %%
new_seoulHanbok = df_seoulHanbok.drop(['연도','월'], axis=1)
new_seoulHanbok.head()
# Out:
#    경복궁(주·야간 착용자)  창덕궁(주·야간 착용자)  덕수궁(주·야간 착용자)  창경궁(주·야간 착용자)  종묘(주간 착용자)  \
# 0          63939           6797          206.0            921        12.0
# 1          27365           3010          209.0            483        13.0
# 2           2282            927           38.0            225         0.0
# 3           3533            976           50.0            395        13.0
# 4           4397           1133           81.0            414         9.0
#
#        연도월
# 0  2020년1월
# 1  2020년2월
# 2  2020년3월
# 3  2020년4월
# 4  2020년5월

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,10))
plt.subplots_adjust(wspace=0.2)
sns.lineplot(data=new_seoulHanbok, x='연도월', y='경복궁(주·야간 착용자)', ci=None, ax=axes[0,0])
sns.lineplot(data=new_seoulHanbok, x='연도월', y='창덕궁(주·야간 착용자)', ci=None, ax=axes[0,1])
sns.lineplot(data=new_seoulHanbok, x='연도월', y='덕수궁(주·야간 착용자)', ci=None, ax=axes[1,0])
sns.lineplot(data=new_seoulHanbok, x='연도월', y='창경궁(주·야간 착용자)', ci=None, ax=axes[1,1])
plt.show()
