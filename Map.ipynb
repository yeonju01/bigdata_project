# %%
import folium
                        #위도       #경도
m = folium.Map(location=[37.57979553563546, 126.97701954027305],zoom_start=13)
folium.Marker([37.57979553563546, 126.97701954027305], popup="경복궁").add_to(m)
folium.CircleMarker(
        location=[37.57979553563546, 126.97701954027305],
        radius=10,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.56595309437314, 126.97515108075113],
        radius=10,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.57892382941064, 126.99488052678042],
        radius=10,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.57964382693289, 126.99106312150094],
        radius=10,
        color="red",
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.571, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, zoom_start=10)
folium.CircleMarker(
        location=[37.62029273846351, 127.12803474212427],
        popup='동구릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.758000223634234, 127.17634793881248],
        popup='광릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.633371105813765, 127.20862229104475],
        popup='홍유릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.64748804280107, 127.1974464267818],
        popup='사릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.64086953621068, 127.09805730308814],
        popup='태릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.60328964889395, 127.0061191042113],
        popup='정릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.466307338709186, 127.08299702677775],
        popup='헌릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.50879223093546, 127.04906066432343],
        popup='선릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.60402717731655, 127.05749295376658],
        popup='의릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.588641506112076, 127.04359701143767],
        popup='영휘원',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.6259826326185, 126.89812612678139],
        popup='서오릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.66434017322836, 126.86870643839673],
        popup='서삼릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.211842103477956, 126.99367899793646],
        popup='융릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.74072674895861, 126.84230146911258],
        popup='파주삼릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.77374190850644, 126.7080928844562],
        popup='파주장릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.613045858110226, 126.71115199794535],
        popup='김포장릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.72106454234554, 126.94961211144054],
        popup='양주온릉',
        radius=7,
        color="red",
    ).add_to(m)
folium.CircleMarker(
        location=[37.30481039503602, 127.60585759793851],
        popup='세종대왕유적',
        radius=7,
        color="red",
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 서울시 중심부
center = [37.575, 126.986]

m = folium.Map(location=center, zoom_start=14)
folium.Marker(
        location=[37.57979553563546, 126.97701954027305],
        popup='경복궁',
        icon=folium.Icon(color='red',icon='ok')
    ).add_to(m)
folium.Marker(
        location=[37.56595309437314, 126.97515108075113],
        popup='덕수궁',
        icon=folium.Icon(color='orange',icon='ok')
    ).add_to(m)
folium.Marker(
        location=[37.57965243829568, 126.99100947732234],
        popup='창덕궁',
        icon=folium.Icon(color='blue',icon='ok')
    ).add_to(m)
folium.Marker(
        location=[37.57896634316321, 126.99488052678042],
        popup='창경궁',
        icon=folium.Icon(color='green',icon='ok')
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
